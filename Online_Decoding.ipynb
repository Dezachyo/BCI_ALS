# %%
### First, import necessary packages

# Some standard pythonic imports
import warnings
warnings.filterwarnings('ignore')
import os,numpy as np,pandas as pd
from collections import OrderedDict
import seaborn as sns
import matplotlib
from matplotlib import pyplot as plt
import pathlib
from os import listdir
from os.path import isfile, join
import pyxdf
import PyQt5
import time
import random
import pickle

from subfunctions import *

from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression

# Scikit-learn and Pyriemann ML functionalities
from sklearn.pipeline import make_pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
from sklearn.model_selection import cross_val_score, StratifiedShuffleSplit
from pyriemann.estimation import ERPCovariances, XdawnCovariances, Xdawn
from pyriemann.tangentspace import TangentSpace
from pyriemann.classification import MDM


# MNE functions
import mne
from mne import Epochs,find_events
from mne.datasets import sample
from mne.io import read_raw_fif
from mne.decoding import (SlidingEstimator, GeneralizingEstimator, Scaler,
                          cross_val_multiscore, LinearModel, get_coef,
                          Vectorizer, CSP)
# Real-time Functionalities
from mne_realtime import LSLClient

# Lab Streaming Layer
from pylsl import *


from joblib import dump, load

# For interactive plots
from IPython import get_ipython
get_ipython().run_line_magic('matplotlib', 'qt')

from easygui import *

# %% [markdown]
# ### Load Prediction Model

# %%
current_path = pathlib.Path().absolute()  
##recording_path = (f"{current_path}\Data\Raw Data")

model_path = (f"{current_path}\Models")

model_files = [f for f in listdir(model_path) if isfile(join(model_path, f))]

# message to be displayed
text = "Choose Model File:"
  
# window title
title = "Model File"
  
# item choices
choices = model_files
  
# creating a button box
model_name = choicebox(text, title, choices)

print (f"Model file: {model_name}")
model_path = (f"{model_path}\{model_name}")

with open(model_path, "rb") as file:
    loaded_model = load(file)
# Out:
# Model file: sub-Synt_ses-Synt_task-3_Class_run-001_eeg_model

# %%
lowPass = loaded_model.bandwidthfilter.l_freq
highPass = loaded_model.bandwidthfilter.h_freq
filterMethod = loaded_model.bandwidthfilter.method
chNames = loaded_model.ch_names

# %%
def online_prediction(Data,input_shape,model):
    assert len(Data.shape) == 3, 'X is not 3D'
    assert Data.shape[1] == input_shape[1] , 'Number of electrodes differs'
    assert Data.shape[2] >= input_shape[2] , 'Data is too short'
    Data = Data[:,:,0:input_shape[2]]
    pred_y = model.predict(Data)
    return pred_y

# %%
## Assign channel names for online EEG stream
ch_names = ['C3','C4','Cz','FC1','FC2','FC5','FC6','CP1','CP2','CP5','CP6','O1','O2']

# %%
# First find our Unity P300 marker stream,
stream_name = "P300_Markers"
stream_info = pylsl.resolve_stream("name", stream_name)

if stream_info is not None:
    # create an inlet for the stream
    inlet = pylsl.StreamInlet(stream_info[0])
    print(f"Connected to {stream_name}")
else:
    print(f"Stream {stream_name} not found")
    
epoch_list=[]
realY=[]
i=0
flag = True
wait_max = 5
# main function is necessary here to enable script as own program
# in such way a child process can be started (primarily for Windows)
if __name__ == '__main__':
    with LSLClient(info=None, host='openbcigui', wait_max=wait_max) as client:
        client_info = client.get_measurement_info()
        sfreq = int(client_info['sfreq'])
        
        ## Create an outlet lsl marker stream for model decision
        info = StreamInfo('DecisionMarkerStream', 'Markers', 1, 0, 'string', 'myuidw43536')
        outlet = StreamOutlet(info)
        markernames = ['Y', 'N']
        
        ## Wait in 'while' loop during sampling
        while (flag):
            # get a new sample 
            sample, timestamp = inlet.pull_sample()
            
            if (sample[0] == 'Target Trial'):
                epoch = client.get_data_as_epoch(n_samples=151) # keep target trials data to epochs
                filt = epoch.filter(lowPass, highPass, method=filterMethod)
                epoch_list.append(epoch)
            if (sample[0] == 'Break'):
                flag = False
            print("got %s at time %s" % (sample[0], timestamp)) # Log of incoming samples
        
print('Streams closed')
concat_epochs = mne.concatenate_epochs(epoch_list)
time.sleep(0.2)


concat_epochs.info = mne.create_info(ch_names = ch_names, sfreq=sfreq)
concat_epochs.pick(chNames)

data = concat_epochs.get_data()

pred = online_prediction(data,loaded_model.input_shape,loaded_model.clsf)
sum(pred)
len(pred)

## Decide 
if (sum(pred)/len(pred) >= 0.5):
    #send Unity trigger to show 'Yes' answer
    outlet.push_sample(markernames[0])
else:
    #send Unity trigger to show 'No' answer
    outlet.push_sample(markernames[1])
# Out:
# Connected to P300_Markers
# Client: Waiting for server to start
# Looking for LSL stream openbcigui...
# Found stream 'obci_eeg1' via openbcigui...
# Client: Connected
# got Distractor Trial at time 217902.7968646
# got Distractor Trial at time 217903.5109507
# got Distractor Trial at time 217904.2954575
# got Distractor Trial at time 217905.1942058
# got Distractor Trial at time 217905.9464431
# got Distractor Trial at time 217906.7479855
# got Non-Target Trial at time 217907.4133418
# got Distractor Trial at time 217908.1820723
# got Distractor Trial at time 217908.8440483
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Setting up band-pass filter from 1 - 40 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 1.00, 40.00 Hz: -6.02, -6.02 dB
#
# got Target Trial at time 217909.6457147
# got Distractor Trial at time 217910.4790573
# got Distractor Trial at time 217911.2272096
# got Distractor Trial at time 217911.8465093
# got Distractor Trial at time 217912.6947414
# got Distractor Trial at time 217913.3935909
# got Distractor Trial at time 217913.9771791
# got Non-Target Trial at time 217914.7612234
# got Distractor Trial at time 217915.4463912
# got Distractor Trial at time 217916.1435756
# got Non-Target Trial at time 217916.8937467
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Setting up band-pass filter from 1 - 40 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 1.00, 40.00 Hz: -6.02, -6.02 dB
#
# got Target Trial at time 217917.6114249
# got Distractor Trial at time 217918.2267666
# got Distractor Trial at time 217918.9769163
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Setting up band-pass filter from 1 - 40 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 1.00, 40.00 Hz: -6.02, -6.02 dB
#
# got Target Trial at time 217919.6782306
# got Distractor Trial at time 217920.2944727
# got Distractor Trial at time 217920.9930694
# got Distractor Trial at time 217921.709954
# got Distractor Trial at time 217922.5270355
# got Distractor Trial at time 217923.1941955
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Setting up band-pass filter from 1 - 40 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 1.00, 40.00 Hz: -6.02, -6.02 dB
#
# got Target Trial at time 217923.9775021
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Setting up band-pass filter from 1 - 40 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 1.00, 40.00 Hz: -6.02, -6.02 dB
#
# got Target Trial at time 217924.7767237
# got Non-Target Trial at time 217925.5270336
# got Distractor Trial at time 217926.3431411
# got Distractor Trial at time 217927.0128114
# got Distractor Trial at time 217927.6269723
# got Distractor Trial at time 217928.2932118
# got Distractor Trial at time 217929.1599367
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Setting up band-pass filter from 1 - 40 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 1.00, 40.00 Hz: -6.02, -6.02 dB
#
# got Target Trial at time 217930.0301398
# got Non-Target Trial at time 217930.6286171
# got Distractor Trial at time 217931.3767117
# got Distractor Trial at time 217932.195378
# got Distractor Trial at time 217933.06024
# got Distractor Trial at time 217933.7452024
# got Distractor Trial at time 217934.6308344
# got Non-Target Trial at time 217935.4100612
# got Non-Target Trial at time 217936.175964
# got Non-Target Trial at time 217937.0094843
# got Non-Target Trial at time 217937.6289885
# got Non-Target Trial at time 217938.2259602
# got Distractor Trial at time 217939.0265179
# got Distractor Trial at time 217939.6119419
# got Non-Target Trial at time 217940.3596333
# got Non-Target Trial at time 217941.1959555
# got Distractor Trial at time 217941.8761948
# got Distractor Trial at time 217942.4287582
# got Distractor Trial at time 217943.2262835
# got Distractor Trial at time 217943.8933501
# got Distractor Trial at time 217944.6778672
# got Distractor Trial at time 217945.4433841
# got Distractor Trial at time 217945.9934432
# got Distractor Trial at time 217946.6761384
# got Non-Target Trial at time 217947.4256309
# got Distractor Trial at time 217948.1255725
# got Non-Target Trial at time 217948.8259645
# got Distractor Trial at time 217949.6092713
# got Distractor Trial at time 217950.2107068
# got Distractor Trial at time 217951.059243
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Setting up band-pass filter from 1 - 40 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 1.00, 40.00 Hz: -6.02, -6.02 dB
#
# got Target Trial at time 217951.9436105
# got Distractor Trial at time 217952.6597827
# got Distractor Trial at time 217953.4256643
# got Non-Target Trial at time 217954.0095775
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Setting up band-pass filter from 1 - 40 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 1.00, 40.00 Hz: -6.02, -6.02 dB
#
# got Target Trial at time 217954.7761186
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Setting up band-pass filter from 1 - 40 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 1.00, 40.00 Hz: -6.02, -6.02 dB
#
# got Target Trial at time 217955.4775579
# got Distractor Trial at time 217956.1756205
# got Distractor Trial at time 217956.875656
# got Distractor Trial at time 217957.4421746
# got Non-Target Trial at time 217958.0084312
# got Distractor Trial at time 217958.6429005
# got Distractor Trial at time 217959.3084885
# got Non-Target Trial at time 217960.0617488
# got Distractor Trial at time 217960.7768694
# got Distractor Trial at time 217961.4085606
# got Non-Target Trial at time 217962.1088977
# got Distractor Trial at time 217962.8760447
# got Distractor Trial at time 217963.6587325
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Setting up band-pass filter from 1 - 40 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 1.00, 40.00 Hz: -6.02, -6.02 dB
#
# got Target Trial at time 217964.3930435
# got Distractor Trial at time 217965.0251508
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Setting up band-pass filter from 1 - 40 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 1.00, 40.00 Hz: -6.02, -6.02 dB
#
# got Target Trial at time 217965.7619202
# got Distractor Trial at time 217966.5082214
# got Distractor Trial at time 217967.2752745
# got Non-Target Trial at time 217968.1082767
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Setting up band-pass filter from 1 - 40 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 1.00, 40.00 Hz: -6.02, -6.02 dB
#
# got Target Trial at time 217968.8105939
# got Distractor Trial at time 217969.541742
# got Distractor Trial at time 217970.3918688
# got Non-Target Trial at time 217971.17519
# got Distractor Trial at time 217971.9584535
# got Non-Target Trial at time 217972.6420969
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Setting up band-pass filter from 1 - 40 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 1.00, 40.00 Hz: -6.02, -6.02 dB
#
# got Target Trial at time 217973.2747149
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Setting up band-pass filter from 1 - 40 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 1.00, 40.00 Hz: -6.02, -6.02 dB
#
# got Target Trial at time 217974.0420294
# got Non-Target Trial at time 217974.9078444
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Setting up band-pass filter from 1 - 40 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 1.00, 40.00 Hz: -6.02, -6.02 dB
#
# got Target Trial at time 217975.7916712
# got Non-Target Trial at time 217976.6425049
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Setting up band-pass filter from 1 - 40 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 1.00, 40.00 Hz: -6.02, -6.02 dB
#
# got Target Trial at time 217977.425381
# got Distractor Trial at time 217978.0766436
# got Non-Target Trial at time 217978.8413013
# got Non-Target Trial at time 217979.5250638
# got Distractor Trial at time 217980.274551
# got Non-Target Trial at time 217981.0582438
# got Distractor Trial at time 217981.642186
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Setting up band-pass filter from 1 - 40 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 1.00, 40.00 Hz: -6.02, -6.02 dB
#
# got Target Trial at time 217982.4586586
# got Non-Target Trial at time 217983.1775172
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Setting up band-pass filter from 1 - 40 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 1.00, 40.00 Hz: -6.02, -6.02 dB
#
# got Target Trial at time 217983.9103281
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Setting up band-pass filter from 1 - 40 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 1.00, 40.00 Hz: -6.02, -6.02 dB
#
# got Target Trial at time 217984.5904451
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Setting up band-pass filter from 1 - 40 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 1.00, 40.00 Hz: -6.02, -6.02 dB
#
# got Target Trial at time 217985.1910754
# got Distractor Trial at time 217985.8918885
# got Distractor Trial at time 217986.7250909
# got Non-Target Trial at time 217987.5907715
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Setting up band-pass filter from 1 - 40 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 1.00, 40.00 Hz: -6.02, -6.02 dB
#
# got Target Trial at time 217988.2906306
# got Distractor Trial at time 217989.1613098
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Setting up band-pass filter from 1 - 40 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 1.00, 40.00 Hz: -6.02, -6.02 dB
#
# got Target Trial at time 217989.7576023
# got Distractor Trial at time 217990.4415353
# got Distractor Trial at time 217991.2239744
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Setting up band-pass filter from 1 - 40 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 1.00, 40.00 Hz: -6.02, -6.02 dB
#
# got Target Trial at time 217991.8909102
# got Distractor Trial at time 217992.6577251
# got Distractor Trial at time 217993.3407225
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Setting up band-pass filter from 1 - 40 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 1.00, 40.00 Hz: -6.02, -6.02 dB
#
# got Target Trial at time 217993.9912104
# got Non-Target Trial at time 217994.807518
# got Distractor Trial at time 217995.5070549
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Setting up band-pass filter from 1 - 40 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 1.00, 40.00 Hz: -6.02, -6.02 dB
#
# got Target Trial at time 217996.2088344
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Setting up band-pass filter from 1 - 40 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 1.00, 40.00 Hz: -6.02, -6.02 dB
#
# got Target Trial at time 217996.9740672
# got Non-Target Trial at time 217997.6405975
# got Distractor Trial at time 217998.4073581
# got Distractor Trial at time 217998.9735619
# got Non-Target Trial at time 217999.6403154
# got Distractor Trial at time 218000.4402904
# got Distractor Trial at time 218001.1236003
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Setting up band-pass filter from 1 - 40 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 1.00, 40.00 Hz: -6.02, -6.02 dB
#
# got Target Trial at time 218001.7402564
# got Distractor Trial at time 218002.4569905
# got Distractor Trial at time 218003.2911386
# got Distractor Trial at time 218004.1407448
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Setting up band-pass filter from 1 - 40 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 1.00, 40.00 Hz: -6.02, -6.02 dB
#
# got Target Trial at time 218004.7584566
# got Distractor Trial at time 218005.5581007
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Setting up band-pass filter from 1 - 40 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 1.00, 40.00 Hz: -6.02, -6.02 dB
#
# got Target Trial at time 218006.2742389
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Setting up band-pass filter from 1 - 40 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 1.00, 40.00 Hz: -6.02, -6.02 dB
#
# got Target Trial at time 218007.0414337
# got Non-Target Trial at time 218007.9067214
# got Distractor Trial at time 218008.7068453
# got Distractor Trial at time 218009.4567265
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Setting up band-pass filter from 1 - 40 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 1.00, 40.00 Hz: -6.02, -6.02 dB
#
# got Target Trial at time 218010.0920087
# got Distractor Trial at time 218010.9563522
# got Distractor Trial at time 218011.6743737
# got Distractor Trial at time 218012.524078
# got Non-Target Trial at time 218013.3060411
# got Distractor Trial at time 218014.1583488
# got Distractor Trial at time 218014.8731548
# got Distractor Trial at time 218015.5059607
# got Distractor Trial at time 218016.3587642
# got Distractor Trial at time 218017.0232199
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Setting up band-pass filter from 1 - 40 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 1.00, 40.00 Hz: -6.02, -6.02 dB
#
# got Target Trial at time 218017.6743507
# got Distractor Trial at time 218018.4063609
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Setting up band-pass filter from 1 - 40 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 1.00, 40.00 Hz: -6.02, -6.02 dB
#
# got Target Trial at time 218019.156714
# got Distractor Trial at time 218019.8895509
# got Distractor Trial at time 218020.6395999
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Setting up band-pass filter from 1 - 40 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 1.00, 40.00 Hz: -6.02, -6.02 dB
#
# got Target Trial at time 218021.3060756
# got Distractor Trial at time 218021.9558438
# got Non-Target Trial at time 218022.7076016
# got Distractor Trial at time 218023.4073973
# got Distractor Trial at time 218024.0065044
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Setting up band-pass filter from 1 - 40 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 1.00, 40.00 Hz: -6.02, -6.02 dB
#
# got Target Trial at time 218024.6246303
# got Distractor Trial at time 218025.3425405
# got Distractor Trial at time 218026.0399213
# got Non-Target Trial at time 218026.9404595
# got Distractor Trial at time 218027.67406
# got Distractor Trial at time 218028.4078662
# got Distractor Trial at time 218029.1072783
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Setting up band-pass filter from 1 - 40 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 1.00, 40.00 Hz: -6.02, -6.02 dB
#
# got Target Trial at time 218029.8425492
# got Distractor Trial at time 218030.5737858
# got Distractor Trial at time 218031.1608926
# got Distractor Trial at time 218031.9086335
# got Distractor Trial at time 218032.5904101
# got Non-Target Trial at time 218033.3402033
# got Break at time 218034.1073028
# Streams closed
# Not setting metadata
# 36 matching events found
# No baseline correction applied

# %% [markdown]
# ### Save online data for future analysis

# %% [markdown]
# fif_export_path = (f"{current_path}\Data\Processed Data\{recording_file[:-4]}_Online.fif")
# epochs.save(fif_export_path)
