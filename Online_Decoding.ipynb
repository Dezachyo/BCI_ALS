# %%
### First, import necessary packages

# Some standard pythonic imports
import numpy as np
from collections import Counter
import warnings
warnings.filterwarnings('ignore')
import os,numpy as np,pandas as pd
from collections import OrderedDict
import seaborn as sns
import matplotlib
from matplotlib import pyplot as plt
import pathlib
from os import listdir
from os.path import isfile, join
import pyxdf
import PyQt5
import time
import random
import pickle

from subfunctions import *

from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression

# Scikit-learn and Pyriemann ML functionalities
from sklearn.pipeline import make_pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
from sklearn.model_selection import cross_val_score, StratifiedShuffleSplit
from pyriemann.estimation import ERPCovariances, XdawnCovariances, Xdawn
from pyriemann.tangentspace import TangentSpace
from pyriemann.classification import MDM


# MNE functions
import mne
from mne import Epochs,find_events
from mne.datasets import sample
from mne.io import read_raw_fif
from mne.decoding import (SlidingEstimator, GeneralizingEstimator, Scaler,
                          cross_val_multiscore, LinearModel, get_coef,
                          Vectorizer, CSP)
# Real-time Functionalities
from mne_realtime import LSLClient

# Lab Streaming Layer
from pylsl import *


from joblib import dump, load

# For interactive plots
from IPython import get_ipython
get_ipython().run_line_magic('matplotlib', 'qt')

from easygui import *

# %% [markdown]
# ### Load Prediction Model

# %%
current_path = pathlib.Path().absolute()  
##recording_path = (f"{current_path}\Data\Raw Data")

model_path = (f"{current_path}\Models")

model_files = [f for f in listdir(model_path) if isfile(join(model_path, f))]

# message to be displayed
text = "Choose Model File:"
  
# window title
title = "Model File"
  
# item choices
choices = model_files # Use GUI to load files
  
# creating a button box
model_name = choicebox(text, title, choices)

print (f"Model file: {model_name}")
model_path = (f"{model_path}\{model_name}")

with open(model_path, "rb") as file:
    loaded_model = load(file)
# Out:
# Model file: Shahar_3_Class_model

# %%
# Get parameters regarding the model (input shape, filter)
lowPass = loaded_model.bandwidthfilter.l_freq
highPass = loaded_model.bandwidthfilter.h_freq
filterMethod = loaded_model.bandwidthfilter.method
chNames = loaded_model.ch_names

# %%
def online_prediction(Data,input_shape,model): # Model prediction for a block 
    assert len(Data.shape) == 3, 'X is not 3D'
    assert Data.shape[1] == input_shape[1] , 'Number of electrodes differs'
    assert Data.shape[2] >= input_shape[2] , 'Data is too short'
    Data = Data[:,:,0:input_shape[2]]
    pred_y = model.predict(Data)
    return pred_y
def decide(pred): # preform voting to decide upon classification 
    vote =  Counter(pred).most_common(1)[0][0] # get predictions winners 
    vote == loaded_model.conditions_dict
    target_lable = [k for k, v in loaded_model.conditions_dict.items() if v == 'Target Trial'] # if target or not
    return target_lable[0] == vote

# %%
## Assign channel names for online EEG stream
ch_names = ['C3','C4','Cz','FC1','FC2','FC5','FC6','CP1','CP2','CP5','CP6','O1','O2']

# %%
# First find our Unity P300 marker stream,
stream_name = "P300_Markers"
stream_info = pylsl.resolve_stream("name", stream_name)

if stream_info is not None:
    # create an inlet for the stream
    inlet = pylsl.StreamInlet(stream_info[0])
    print(f"Connected to {stream_name}")
else:
    print(f"Stream {stream_name} not found")
    
epoch_list=[]
realY=[]
i=0
flag = True
wait_max = 5
# main function is necessary here to enable script as own program
# in such way a child process can be started (primarily for Windows)
if __name__ == '__main__':
    with LSLClient(info=None, host='openbcigui', wait_max=wait_max) as client:
        client_info = client.get_measurement_info()
        sfreq = int(client_info['sfreq'])
        
        ## Create an outlet lsl marker stream for model decision
        info = StreamInfo('DecisionMarkerStream', 'Markers', 1, 0, 'string', 'myuidw43536')
        outlet = StreamOutlet(info)
        markernames = ['Y', 'N']
        
        ## Wait in 'while' loop during sampling
        while (flag):
            # get a new sample 
            sample, timestamp = inlet.pull_sample()
            
            if (sample[0] == 'Target Trial'):
                epoch = client.get_data_as_epoch(n_samples=151) # keep target trials data to epochs
                filt = epoch.filter(lowPass, highPass, method=filterMethod)
                epoch_list.append(epoch)
            if (sample[0] == 'Break'):
                flag = False
            print("got %s at time %s" % (sample[0], timestamp)) # Log of incoming samples
        
print('Streams closed')
concat_epochs = mne.concatenate_epochs(epoch_list)
time.sleep(0.2)


concat_epochs.info = mne.create_info(ch_names = ch_names, sfreq=sfreq)
concat_epochs.pick(chNames)

data = concat_epochs.get_data()

pred = online_prediction(data,loaded_model.input_shape,loaded_model.clsf)


## Decide 
if (decide(pred)):
    #send Unity trigger to show 'Yes' answer
    outlet.push_sample(markernames[0])
else:
    #send Unity trigger to show 'No' answer
    outlet.push_sample(markernames[1])
# Out:
# Connected to P300_Markers
# Client: Waiting for server to start
# Looking for LSL stream openbcigui...
# Found stream 'obci_eeg1' via openbcigui...
# Client: Connected
# got Distractor Trial at time 70906.9732953
# got Distractor Trial at time 70907.6057996
# got Distractor Trial at time 70908.3212945
# got Distractor Trial at time 70909.0725706
# got Distractor Trial at time 70909.8723638
# got Non-Target Trial at time 70910.6893288
# got Distractor Trial at time 70911.4216848
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Setting up band-pass filter from 1 - 40 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 1.00, 40.00 Hz: -6.02, -6.02 dB
#
# got Target Trial at time 70912.2044574
# got Distractor Trial at time 70913.0379276
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Setting up band-pass filter from 1 - 40 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 1.00, 40.00 Hz: -6.02, -6.02 dB
#
# got Target Trial at time 70913.7736857
# got Distractor Trial at time 70914.5049538
# got Non-Target Trial at time 70915.1877137
# got Non-Target Trial at time 70915.9069799
# got Non-Target Trial at time 70916.4870261
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Setting up band-pass filter from 1 - 40 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 1.00, 40.00 Hz: -6.02, -6.02 dB
#
# got Target Trial at time 70917.2229005
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Setting up band-pass filter from 1 - 40 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 1.00, 40.00 Hz: -6.02, -6.02 dB
#
# got Target Trial at time 70918.0046414
# got Distractor Trial at time 70918.8575919
# got Non-Target Trial at time 70919.5555559
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Setting up band-pass filter from 1 - 40 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 1.00, 40.00 Hz: -6.02, -6.02 dB
#
# got Target Trial at time 70920.2213023
# got Distractor Trial at time 70920.8877745
# got Distractor Trial at time 70921.5054314
# got Distractor Trial at time 70922.371262
# got Distractor Trial at time 70923.1042333
# got Distractor Trial at time 70923.8205043
# got Non-Target Trial at time 70924.4554272
# got Distractor Trial at time 70925.3209373
# got Distractor Trial at time 70926.0895938
# got Distractor Trial at time 70926.6559378
# got Distractor Trial at time 70927.3748521
# got Distractor Trial at time 70928.02331
# got Distractor Trial at time 70928.7905026
# got Non-Target Trial at time 70929.5568984
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Setting up band-pass filter from 1 - 40 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 1.00, 40.00 Hz: -6.02, -6.02 dB
#
# got Target Trial at time 70930.2554844
# got Distractor Trial at time 70930.9394375
# got Distractor Trial at time 70931.5730279
# got Non-Target Trial at time 70932.4055535
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Setting up band-pass filter from 1 - 40 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 1.00, 40.00 Hz: -6.02, -6.02 dB
#
# got Target Trial at time 70933.1617934
# got Distractor Trial at time 70933.905436
# got Distractor Trial at time 70934.5888144
# got Distractor Trial at time 70935.3720505
# got Distractor Trial at time 70936.2086807
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Setting up band-pass filter from 1 - 40 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 1.00, 40.00 Hz: -6.02, -6.02 dB
#
# got Target Trial at time 70936.9407875
# got Distractor Trial at time 70937.607779
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Setting up band-pass filter from 1 - 40 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 1.00, 40.00 Hz: -6.02, -6.02 dB
#
# got Target Trial at time 70938.4412836
# got Distractor Trial at time 70939.173072
# got Distractor Trial at time 70939.8790481
# got Non-Target Trial at time 70940.5915761
# got Non-Target Trial at time 70941.4269507
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Setting up band-pass filter from 1 - 40 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 1.00, 40.00 Hz: -6.02, -6.02 dB
#
# got Target Trial at time 70942.0585853
# got Non-Target Trial at time 70942.6767868
# got Distractor Trial at time 70943.377897
# got Distractor Trial at time 70944.0762542
# got Distractor Trial at time 70944.6754897
# got Non-Target Trial at time 70945.2916936
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Setting up band-pass filter from 1 - 40 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 1.00, 40.00 Hz: -6.02, -6.02 dB
#
# got Target Trial at time 70946.0105065
# got Distractor Trial at time 70946.6438201
# got Distractor Trial at time 70947.4761396
# got Distractor Trial at time 70948.2948602
# got Distractor Trial at time 70949.041968
# got Distractor Trial at time 70949.6751003
# got Distractor Trial at time 70950.425457
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Setting up band-pass filter from 1 - 40 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 1.00, 40.00 Hz: -6.02, -6.02 dB
#
# got Target Trial at time 70951.209357
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Setting up band-pass filter from 1 - 40 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 1.00, 40.00 Hz: -6.02, -6.02 dB
#
# got Target Trial at time 70951.7922665
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Setting up band-pass filter from 1 - 40 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 1.00, 40.00 Hz: -6.02, -6.02 dB
#
# got Target Trial at time 70952.5747566
# got Non-Target Trial at time 70953.24224
# got Distractor Trial at time 70953.9754489
# got Non-Target Trial at time 70954.7590926
# got Distractor Trial at time 70955.4738403
# got Distractor Trial at time 70956.2084957
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Setting up band-pass filter from 1 - 40 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 1.00, 40.00 Hz: -6.02, -6.02 dB
#
# got Target Trial at time 70957.0245223
# got Distractor Trial at time 70957.7595396
# got Distractor Trial at time 70958.4246602
# got Non-Target Trial at time 70959.1576694
# got Distractor Trial at time 70959.8580599
# got Distractor Trial at time 70960.5768023
# got Break at time 70961.2245689
# Streams closed
# Not setting metadata
# 15 matching events found
# No baseline correction applied

# %%
Counter(pred)
# Out:
# Counter({3: 7, 1: 6, 2: 2})

# %% [markdown]
# ### Save online data for future analysis

# %% [markdown]
# fif_export_path = (f"{current_path}\Data\Processed Data\{recording_file[:-4]}_Online.fif")
# epochs.save(fif_export_path)
